# %% [markdown]
# <a href="https://colab.research.google.com/github/wern3ck/programacao-em-python/blob/master/Fun%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Funções
#
# - Trechos de programa que recebem um determinado nome e podem ser chamados várias vezes durante a execução
# - Principais vantagens: reutilização de código, modularidade e facilidade de manutenção do sistema

# %% [markdown]
# ## Função sem parâmetro e sem retorno

# %%
def mensagem():
  print('Texto da função')

# %%
mensagem()
mensagem()
mensagem()
# Out:
# Texto da função
# Texto da função
# Texto da função

# %% [markdown]
# ## Função com passagem de parâmetro

# %%
def mensagem(texto):
  print(texto)

# %%
mensagem('texto 1')
mensagem('texto 2')
mensagem('texto 3')
# Out:
# texto 1
# texto 2
# texto 3

# %%
def soma(a, b):
  print(a + b)

# %%
soma(2, 3)
# Out:
# 5

# %%
soma(3, 3)
soma(1, 2)
# Out:
# 6
# 3

# %% [markdown]
# ## Função com passagem de parâmetros e retorno

# %%
def soma(a, b):
  return a + b

# %%
soma(3, 2)
# Out:
# 5

# %%
# r = 7
r = soma(3, 2)
print(r)
# Out:
# 5
